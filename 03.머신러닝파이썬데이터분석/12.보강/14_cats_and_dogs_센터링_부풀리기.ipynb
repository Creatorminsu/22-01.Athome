# %% [markdown]
# # 고양이, 개 분류 - CNN v2
# - Dropout 추가
# - 이미지를 중앙에 배치
# - 각 이미지를 10개씩 부풀려 파일로 저장하고 이 파일로 학습

# %%
import cv2, os
import numpy as np
from tqdm.notebook import tqdm
from PIL import Image
import matplotlib.pyplot as plt

# %%
# !wget https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip
# Out:
# --2022-01-23 08:54:10--  https://storage.googleapis.com/mledu-datasets/cats_and_dogs_filtered.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.250.152.128, 173.194.196.128, 173.194.197.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.250.152.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 68606236 (65M) [application/zip]
# Saving to: ‘cats_and_dogs_filtered.zip’
#
# cats_and_dogs_filte 100%[===================>]  65.43M   197MB/s    in 0.3s
#
# 2022-01-23 08:54:10 (197 MB/s) - ‘cats_and_dogs_filtered.zip’ saved [68606236/68606236]

# %%
# !unzip cats_and_dogs_filtered.zip > /dev/null

# %% [markdown]
# - 데이터 탐색

# %%
# 이미지를 축소/확대 및 센터링해서 이미지를 리턴하는 함수
IMAGE_SIZE = 150

def center_image(img, format='Image'):
    """입력 img 포맷은 Pillow image, 반환 포맷은 numpy array"""
    if format == 'Image' :              # pillow image
        h, w, _ = np.array(img).shape
    else:                               # numpy array
        h, w = img.shape[:-1]
    if h > w:
        width, height = IMAGE_SIZE, (h * IMAGE_SIZE) // w
    else:
        width, height = (w * IMAGE_SIZE) // h, IMAGE_SIZE

    new_img = np.array(img.resize((width,height)))

    diff = abs(width - height)//2
    if width > height:
        final_img = new_img[:, diff:diff+IMAGE_SIZE, :]
    else:
        final_img = new_img[diff:diff+IMAGE_SIZE, :, :]

    return Image.fromarray(final_img) if format == 'Image' else final_img

# %%
CENTER_DIR = 'cats_and_dogs_centered'
train_dir = f'{CENTER_DIR}/train'
validation_dir = f'{CENTER_DIR}/validation'
train_cats_dir = f'{CENTER_DIR}/train/cats'
train_dogs_dir = f'{CENTER_DIR}/train/dogs'
validation_cats_dir = f'{CENTER_DIR}/validation/cats'
validation_dogs_dir = f'{CENTER_DIR}/validation/dogs'

# %%
if not os.path.exists(CENTER_DIR):
    os.mkdir(CENTER_DIR)
for dir in [train_dir,validation_dir,train_cats_dir,train_dogs_dir,validation_cats_dir,validation_dogs_dir]:
    os.mkdir(dir)

# %%
old_train_cats_dir = 'cats_and_dogs_filtered/train/cats'
old_train_dogs_dir = 'cats_and_dogs_filtered/train/dogs'
old_validation_cats_dir = 'cats_and_dogs_filtered/validation/cats'
old_validation_dogs_dir = 'cats_and_dogs_filtered/validation/dogs'

# %%
# cats_and_dogs_filtered -> image 축소/확대후 centering -> cats_and_dogs_centered
from glob import glob
for src_dir in [old_train_cats_dir,old_train_dogs_dir,old_validation_cats_dir,old_validation_dogs_dir]:
    dst_dir = src_dir.split('/')[1:]            # cats_and_dogs_filtered 제거
    dst_dir = '/'.join([CENTER_DIR] + dst_dir)  # CENTER_DIR 밑에 오는 디렉토리 지정
    for fname in glob(f'{src_dir}/*.jpg'):
        dst_fname = fname.split('/')[-1]    # 예를 들어, cat.475.jpg
        src_img = Image.open(fname)         # 사이즈가 제각각인 이미지
        dst_img = center_image(src_img)     # 150 x 150으로 centering된 이미지(pillow로 변경됨)
        dst_img.save(f'{dst_dir}/{dst_fname}')

# %% [markdown]
# - 이미지 부풀리기

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing.image import img_to_array, load_img

train_datagen = ImageDataGenerator(
    rescale=1/255.,
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.5,
    zoom_range=[0.8, 1.2],
    horizontal_flip=True,
    fill_mode='nearest'
)

# %%
for fname in tqdm(glob(f'{train_cats_dir}/*.jpg')):
    img = load_img(fname)
    x = img_to_array(img)
    x = x.reshape((1,) + x.shape)

    pre = fname.split('.')[1]
    count = 0
    for _ in train_datagen.flow(x, batch_size=1, save_to_dir=train_cats_dir, save_prefix=pre):
        count += 1
        if count >= 10:
            break
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %%
for fname in tqdm(glob(f'{train_dogs_dir}/*.jpg')):
    img = load_img(fname)
    x = img_to_array(img)
    x = x.reshape((1,) + x.shape)

    pre = fname.split('.')[1]
    count = 0
    for _ in train_datagen.flow(x, batch_size=1, save_to_dir=train_dogs_dir, save_prefix=pre):
        count += 1
        if count >= 10:
            break
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %%
len(os.listdir(train_cats_dir)), len(os.listdir(train_dogs_dir))
# Out:
# (10997, 10996)

# %%
plt.figure(figsize=(12,5))
cat_fnames = glob(f'{train_cats_dir}/*')
dog_fnames = glob(f'{train_dogs_dir}/*')
for i in range(5):
    img = Image.open(cat_fnames[i])
    plt.subplot(2,5,i+1)
    plt.imshow(img), plt.title(cat_fnames[i].split('/')[-1]), plt.xticks([]), plt.yticks([])
    img = Image.open(dog_fnames[i])
    plt.subplot(2,5,i+1+5)
    plt.imshow(img), plt.title(dog_fnames[i].split('/')[-1]), plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# - 모델 구성

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

# %%
model = Sequential([
    Conv2D(16, kernel_size=(3,3), input_shape=(150,150,3), activation='relu'),
    MaxPooling2D(),
    Dropout(0.25),
    Conv2D(32, kernel_size=(3,3), activation='relu'),
    MaxPooling2D(),
    Dropout(0.25),
    Conv2D(64, kernel_size=(3,3), activation='relu'),
    MaxPooling2D(),
    Dropout(0.25),
    Flatten(),
    Dense(512, activation='relu'),
    Dropout(0.5),
    Dense(1, activation='sigmoid')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 148, 148, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 74, 74, 16)       0
#  )
#
#  dropout (Dropout)           (None, 74, 74, 16)        0
#
#  conv2d_1 (Conv2D)           (None, 72, 72, 32)        4640
#
#  max_pooling2d_1 (MaxPooling  (None, 36, 36, 32)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 36, 36, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 34, 34, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 17, 17, 64)       0
#  2D)
#
#  dropout_2 (Dropout)         (None, 17, 17, 64)        0
#
#  flatten (Flatten)           (None, 18496)             0
#
#  dense (Dense)               (None, 512)               9470464
#
#  dropout_3 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 9,494,561
# Trainable params: 9,494,561
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# - 모델 설정

# %%
from tensorflow.keras.optimizers import RMSprop

model.compile(
    optimizer=RMSprop(learning_rate=0.001, decay=1e-8),
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# %% [markdown]
# - 파일에서 이미지 데이터 읽어오는 방법

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale=1/255.)
test_datagen = ImageDataGenerator(rescale=1/255.)

# %%
train_generator = train_datagen.flow_from_directory(
    train_dir, batch_size=20, class_mode='binary', target_size=(150,150)
)
validation_generator = test_datagen.flow_from_directory(
    validation_dir, batch_size=20, class_mode='binary', target_size=(150,150)
)
# Out:
# Found 21993 images belonging to 2 classes.
# Found 1000 images belonging to 2 classes.

# %% [markdown]
# - callback 정의

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

model_path = 'best-cat-dog-v3.h5'
checkpoint = ModelCheckpoint(model_path, save_best_only=True, verbose=1)
early_stop = EarlyStopping(patience=10)

# %% [markdown]
# - 모델 실행

# %%
hist = model.fit(
    train_generator,
    validation_data=validation_generator,
    epochs=100,
    steps_per_epoch=100,        # 한번의 epoch에서 훈련에 사용할 batch의 갯수
    validation_steps=50,        # 한번의 epoch가 끝났을 때, 테스트에 사용되는 batch의 갯수
    verbose=2,
    callbacks=[checkpoint, early_stop]
)
# Out:
# Epoch 1/100
#
# Epoch 00001: val_loss improved from inf to 0.68283, saving model to best-cat-dog-v3.h5
# 100/100 - 18s - loss: 0.7957 - accuracy: 0.5355 - val_loss: 0.6828 - val_accuracy: 0.5950 - 18s/epoch - 176ms/step
# Epoch 2/100
#
# Epoch 00002: val_loss improved from 0.68283 to 0.65852, saving model to best-cat-dog-v3.h5
# 100/100 - 6s - loss: 0.6762 - accuracy: 0.6045 - val_loss: 0.6585 - val_accuracy: 0.5940 - 6s/epoch - 56ms/step
# Epoch 3/100
#
# Epoch 00003: val_loss improved from 0.65852 to 0.61094, saving model to best-cat-dog-v3.h5
# 100/100 - 6s - loss: 0.6406 - accuracy: 0.6240 - val_loss: 0.6109 - val_accuracy: 0.6590 - 6s/epoch - 57ms/step
# Epoch 4/100
#
# Epoch 00004: val_loss improved from 0.61094 to 0.61073, saving model to best-cat-dog-v3.h5
# 100/100 - 6s - loss: 0.6028 - accuracy: 0.6720 - val_loss: 0.6107 - val_accuracy: 0.6580 - 6s/epoch - 56ms/step
# Epoch 5/100
#
# Epoch 00005: val_loss improved from 0.61073 to 0.58531, saving model to best-cat-dog-v3.h5
# 100/100 - 6s - loss: 0.6120 - accuracy: 0.6715 - val_loss: 0.5853 - val_accuracy: 0.6860 - 6s/epoch - 55ms/step
# Epoch 6/100
#
# Epoch 00006: val_loss did not improve from 0.58531
# 100/100 - 5s - loss: 0.5901 - accuracy: 0.6755 - val_loss: 0.5912 - val_accuracy: 0.6860 - 5s/epoch - 54ms/step
# Epoch 7/100
#
# Epoch 00007: val_loss improved from 0.58531 to 0.57363, saving model to best-cat-dog-v3.h5
# 100/100 - 6s - loss: 0.5706 - accuracy: 0.6935 - val_loss: 0.5736 - val_accuracy: 0.6950 - 6s/epoch - 56ms/step
# Epoch 8/100
#
# Epoch 00008: val_loss did not improve from 0.57363
# 100/100 - 5s - loss: 0.5938 - accuracy: 0.6895 - val_loss: 0.5926 - val_accuracy: 0.7020 - 5s/epoch - 54ms/step
# Epoch 9/100
#
# Epoch 00009: val_loss did not improve from 0.57363
# 100/100 - 5s - loss: 0.5666 - accuracy: 0.7065 - val_loss: 0.6524 - val_accuracy: 0.6540 - 5s/epoch - 53ms/step
# Epoch 10/100
#
# Epoch 00010: val_loss improved from 0.57363 to 0.56571, saving model to best-cat-dog-v3.h5
# 100/100 - 6s - loss: 0.5734 - accuracy: 0.7150 - val_loss: 0.5657 - val_accuracy: 0.7140 - 6s/epoch - 56ms/step
# Epoch 11/100
#
# Epoch 00011: val_loss improved from 0.56571 to 0.55476, saving model to best-cat-dog-v3.h5
# 100/100 - 6s - loss: 0.5929 - accuracy: 0.7195 - val_loss: 0.5548 - val_accuracy: 0.7240 - 6s/epoch - 56ms/step
# Epoch 12/100
#
# Epoch 00012: val_loss improved from 0.55476 to 0.55173, saving model to best-cat-dog-v3.h5
# 100/100 - 6s - loss: 0.5617 - accuracy: 0.7215 - val_loss: 0.5517 - val_accuracy: 0.7140 - 6s/epoch - 56ms/step
# Epoch 13/100
#
# Epoch 00013: val_loss did not improve from 0.55173
# 100/100 - 5s - loss: 0.5528 - accuracy: 0.7135 - val_loss: 0.5908 - val_accuracy: 0.6960 - 5s/epoch - 54ms/step
# Epoch 14/100
#
# Epoch 00014: val_loss did not improve from 0.55173
# 100/100 - 5s - loss: 0.5288 - accuracy: 0.7465 - val_loss: 0.5875 - val_accuracy: 0.6990 - 5s/epoch - 54ms/step
# Epoch 15/100
#
# Epoch 00015: val_loss did not improve from 0.55173
# 100/100 - 5s - loss: 0.5443 - accuracy: 0.7325 - val_loss: 0.5816 - val_accuracy: 0.6930 - 5s/epoch - 54ms/step
# Epoch 16/100
#
# Epoch 00016: val_loss improved from 0.55173 to 0.52162, saving model to best-cat-dog-v3.h5
# 100/100 - 6s - loss: 0.5338 - accuracy: 0.7470 - val_loss: 0.5216 - val_accuracy: 0.7650 - 6s/epoch - 55ms/step
# Epoch 17/100
#
# Epoch 00017: val_loss improved from 0.52162 to 0.51356, saving model to best-cat-dog-v3.h5
# 100/100 - 6s - loss: 0.5228 - accuracy: 0.7430 - val_loss: 0.5136 - val_accuracy: 0.7690 - 6s/epoch - 56ms/step
# Epoch 18/100
#
# Epoch 00018: val_loss did not improve from 0.51356
# 100/100 - 6s - loss: 0.5137 - accuracy: 0.7575 - val_loss: 0.6466 - val_accuracy: 0.6300 - 6s/epoch - 55ms/step
# Epoch 19/100
#
# Epoch 00019: val_loss improved from 0.51356 to 0.50642, saving model to best-cat-dog-v3.h5
# 100/100 - 6s - loss: 0.5073 - accuracy: 0.7682 - val_loss: 0.5064 - val_accuracy: 0.7440 - 6s/epoch - 57ms/step
# Epoch 20/100
#
# Epoch 00020: val_loss improved from 0.50642 to 0.49019, saving model to best-cat-dog-v3.h5
# 100/100 - 6s - loss: 0.4839 - accuracy: 0.7745 - val_loss: 0.4902 - val_accuracy: 0.7670 - 6s/epoch - 57ms/step
# Epoch 21/100
#
# Epoch 00021: val_loss did not improve from 0.49019
# 100/100 - 5s - loss: 0.5055 - accuracy: 0.7580 - val_loss: 0.5482 - val_accuracy: 0.7350 - 5s/epoch - 54ms/step
# Epoch 22/100
#
# Epoch 00022: val_loss improved from 0.49019 to 0.48010, saving model to best-cat-dog-v3.h5
# 100/100 - 6s - loss: 0.5007 - accuracy: 0.7635 - val_loss: 0.4801 - val_accuracy: 0.7810 - 6s/epoch - 56ms/step
# Epoch 23/100
#
# Epoch 00023: val_loss did not improve from 0.48010
# 100/100 - 5s - loss: 0.4851 - accuracy: 0.7565 - val_loss: 0.4919 - val_accuracy: 0.7740 - 5s/epoch - 55ms/step
# Epoch 24/100
#
# Epoch 00024: val_loss did not improve from 0.48010
# 100/100 - 5s - loss: 0.5006 - accuracy: 0.7540 - val_loss: 0.5340 - val_accuracy: 0.7600 - 5s/epoch - 55ms/step
# Epoch 25/100
#
# Epoch 00025: val_loss did not improve from 0.48010
# 100/100 - 5s - loss: 0.4919 - accuracy: 0.7672 - val_loss: 0.4828 - val_accuracy: 0.7770 - 5s/epoch - 54ms/step
# Epoch 26/100
#
# Epoch 00026: val_loss did not improve from 0.48010
# 100/100 - 5s - loss: 0.4841 - accuracy: 0.7740 - val_loss: 0.5065 - val_accuracy: 0.7730 - 5s/epoch - 54ms/step
# Epoch 27/100
#
# Epoch 00027: val_loss did not improve from 0.48010
# 100/100 - 5s - loss: 0.4653 - accuracy: 0.7800 - val_loss: 0.4806 - val_accuracy: 0.7880 - 5s/epoch - 54ms/step
# Epoch 28/100
#
# Epoch 00028: val_loss improved from 0.48010 to 0.47584, saving model to best-cat-dog-v3.h5
# 100/100 - 6s - loss: 0.4760 - accuracy: 0.7795 - val_loss: 0.4758 - val_accuracy: 0.7930 - 6s/epoch - 56ms/step
# Epoch 29/100
#
# Epoch 00029: val_loss did not improve from 0.47584
# 100/100 - 5s - loss: 0.4581 - accuracy: 0.7965 - val_loss: 0.5240 - val_accuracy: 0.7500 - 5s/epoch - 54ms/step
# Epoch 30/100
#
# Epoch 00030: val_loss did not improve from 0.47584
# 100/100 - 5s - loss: 0.4573 - accuracy: 0.7930 - val_loss: 0.4878 - val_accuracy: 0.7980 - 5s/epoch - 55ms/step
# Epoch 31/100
#
# Epoch 00031: val_loss did not improve from 0.47584
# 100/100 - 5s - loss: 0.4643 - accuracy: 0.7785 - val_loss: 0.4995 - val_accuracy: 0.7650 - 5s/epoch - 54ms/step
# Epoch 32/100
#
# Epoch 00032: val_loss did not improve from 0.47584
# 100/100 - 5s - loss: 0.4754 - accuracy: 0.7815 - val_loss: 0.5239 - val_accuracy: 0.7460 - 5s/epoch - 54ms/step
# Epoch 33/100
#
# Epoch 00033: val_loss did not improve from 0.47584
# 100/100 - 5s - loss: 0.4328 - accuracy: 0.8020 - val_loss: 0.4828 - val_accuracy: 0.7790 - 5s/epoch - 54ms/step
# Epoch 34/100
#
# Epoch 00034: val_loss did not improve from 0.47584
# 100/100 - 5s - loss: 0.4311 - accuracy: 0.8000 - val_loss: 0.4854 - val_accuracy: 0.7730 - 5s/epoch - 54ms/step
# Epoch 35/100
#
# Epoch 00035: val_loss did not improve from 0.47584
# 100/100 - 5s - loss: 0.4511 - accuracy: 0.7920 - val_loss: 0.4918 - val_accuracy: 0.7730 - 5s/epoch - 53ms/step
# Epoch 36/100
#
# Epoch 00036: val_loss did not improve from 0.47584
# 100/100 - 5s - loss: 0.4577 - accuracy: 0.7915 - val_loss: 0.5017 - val_accuracy: 0.7710 - 5s/epoch - 55ms/step
# Epoch 37/100
#
# Epoch 00037: val_loss did not improve from 0.47584
# 100/100 - 5s - loss: 0.4452 - accuracy: 0.8030 - val_loss: 0.5053 - val_accuracy: 0.7630 - 5s/epoch - 55ms/step
# Epoch 38/100
#
# Epoch 00038: val_loss did not improve from 0.47584
# 100/100 - 5s - loss: 0.4253 - accuracy: 0.8085 - val_loss: 0.5581 - val_accuracy: 0.7620 - 5s/epoch - 55ms/step

# %%
from tensorflow.keras.models import load_model
best_model = load_model(model_path)

# %% [markdown]
# - 텍스트 이미지 분류

# %%
from google.colab import files

up = files.upload()
# Out:
#      <input type="file" id="files-1723d31f-eae7-481e-9eeb-80a2e0ef5590" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1723d31f-eae7-481e-9eeb-80a2e0ef5590">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %%
for fname in up.keys():
    img = Image.open(fname)
    img = center_image(img)
    classes = best_model.predict(np.array(img).reshape(1,150,150,3))
    print(f"{classes[0,0]:.4f} {fname} is a {'dog' if classes[0,0] > 0.5 else 'cat'}")

# %% [markdown]
# - 학습과정 시각화

# %%
import numpy as np
y_acc = hist.history['accuracy']
y_vloss = hist.history['val_loss']
xs = np.arange(1, len(y_acc)+1)

# %%
plt.figure(figsize=(12,8))
plt.plot(xs, y_acc, label='train accuracy')
plt.plot(xs, y_vloss, label='validation loss')
plt.legend()
plt.grid()
plt.xlabel('Epoch')
plt.show()
